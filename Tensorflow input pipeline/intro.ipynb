# %%
import tensorflow as tf
import numpy as np
import os

# %%
daily_sales_number = [21,22,-108,31,-1,32,34,31]

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_number)
tf_dataset
# Out:
# <_TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>

# %%
# to see the indivisual elements in a tf dataset you have to iterate through the dataset and apply numpy() function

#method 1
for sales in tf_dataset:
    print(sales.numpy())
# Out:
# 21
# 22
# -108
# 31
# -1
# 32
# 34
# 31

# %%
# method 2
for sale in tf_dataset.as_numpy_iterator():
    print(sale)
# Out:
# 21
# 22
# -108
# 31
# -1
# 32
# 34
# 31

# %%
# if you want to print selectively first elements then use take() method

for sales in tf_dataset.take(3):
    print(sales.numpy())
# Out:
# 21
# 22
# -108

# %%
# if you want to filter some elements like here you want to remove those negative elements as negative sales doesn't exists

filter_dataset = tf_dataset.filter(lambda x: x>0)
for sales in filter_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 21
# 22
# 31
# 32
# 34
# 31

# %%
# if you want to do feature engineering in every element , you can use map function

converted_tp_BD_currency = filter_dataset.map(lambda x: x*120)
for sales in converted_tp_BD_currency:
    print(sales.numpy())
# Out:
# 2520
# 2640
# 3720
# 3840
# 4080
# 3720

# %%
#if you want to shuffle elements us shuffle function

shuffled_dataset = converted_tp_BD_currency.shuffle(3)
for sales in shuffled_dataset:
    print(sales.numpy())
# Out:
# 2640
# 3720
# 4080
# 3720
# 3840
# 2520

# %%
# you can also create batches of dataset

for sales in shuffled_dataset.batch(2):
    print(sales.numpy())
# Out:
# [2640 3840]
# [2520 3720]
# [4080 3720]

# %%
# Now you can do all these things in a single line

new_tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_number)

# %%
etl_dataset = new_tf_dataset.filter(lambda x: x>0).map(lambda y: y*120).shuffle(2).batch(2)
for sales in etl_dataset:
    print(sales.numpy())
# Out:
# [2640 3720]
# [2520 3840]
# [3720 4080]

# %%
image_ds = tf.data.Dataset.list_files('images/*/*', shuffle=False)
for file in image_ds.take(5):
    print(file.numpy())
# Out:
# b'images\\messi\\060724  Lionel Messi of Argentina looks 1920  .jpg'
# b'images\\messi\\1200x675_cmsv2_397eddf0-1e7d-5271-b801-571fc21b14c1-8353416.jpg'
# b'images\\messi\\1710795602070_e0b48d8c-087c-4220-b368-1047fc7dee76.jpg'
# b'images\\messi\\17185783639125.jpg'
# b'images\\messi\\17218817761201.jpg'

# %%
image_ds = image_ds.shuffle(200)
for file in image_ds.take(3):
    print(file.numpy())
# Out:
# b'images\\messi\\GettyImages-1666756533.jpg'
# b'images\\messi\\17185783639125.jpg'
# b'images\\ronaldo\\cristiano-ronaldo-al-nassr-2023-1692731063-114594.jpg'

# %%
image_count = len(image_ds)
image_count
# Out:
# 89

# %%
train_size = int(image_count*0.8)

train_ds = image_ds.take(train_size)
test_ds = image_ds.skip(train_size)

# %%
len(train_ds), len(test_ds)
# Out:
# (71, 18)

# %%
def get_label(file_path):
    return tf.strings.split(file_path, os.path.sep)[-2]

# %%
def process_image(file_path):
    label = get_label(file_path)

    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [128,128])

    return img, label

# %%
train_ds = train_ds.map(process_image)

for img, label in train_ds.take(5):
    print(f"Image: {img}")
    print(f"label: {label}")
# Out:
# Image: [[[  1.5       5.34375  24.34375]
#   [  3.09375  15.15625  34.34375]
#   [  0.        0.       19.     ]
#   ...
#   [ 25.84375  42.84375  72.84375]
#   [  0.       31.       56.     ]
#   [  8.       34.       61.     ]]
#
#  [[ 24.4375   31.4375   53.875  ]
#   [  0.46875   0.59375  16.0625 ]
#   [  0.        0.       19.     ]
#   ...
#   [ 23.0625   40.0625   70.0625 ]
#   [ 10.5      37.03125  64.03125]
#   [  1.90625  28.84375  55.84375]]
#
#  [[  0.        3.71875  24.59375]
#   [  1.        0.       19.125  ]
#   [  0.        0.       19.     ]
#   ...
#   [ 16.0625   36.1875   65.625  ]
#   [ 15.8125   34.8125   64.8125 ]
#   [  0.       25.71875  52.71875]]
#
#  ...
#
#  [[ 84.21875 125.21875  55.21875]
#   [ 83.0625  124.0625   56.0625 ]
#   [ 82.4375  123.4375   54.5625 ]
#   ...
#   [ 68.84375 117.28125  29.96875]
#   [ 67.3125  118.3125   25.3125 ]
#   [ 68.3125  117.3125   26.3125 ]]
#
#  [[ 71.03125 113.03125  40.90625]
#   [ 76.9375  118.46875  47.40625]
#   [ 68.25    110.25     38.125  ]
#   ...
#   [ 76.0625  125.0625   34.     ]
#   [ 66.78125 117.78125  22.78125]
#   [ 67.96875 116.96875  25.90625]]
#
#  [[ 69.46875 111.46875  35.46875]
#   [ 78.71875 120.71875  46.03125]
#   [ 61.59375 104.59375  25.59375]
#   ...
#   [ 67.3125  117.3125   22.3125 ]
#   [ 65.34375 117.34375  19.34375]
#   [ 61.46875 110.46875  18.46875]]]
# label: b'ronaldo'
# Image: [[[20.4375   23.78125  27.      ]
#   [18.595215 19.595215 21.595215]
#   [21.060059 25.060059 26.060059]
#   ...
#   [30.033691 30.033691 30.033691]
#   [29.359375 29.359375 29.359375]
#   [31.       31.       31.      ]]
#
#  [[24.078125 24.078125 25.640625]
#   [22.921875 22.921875 24.921875]
#   [22.9292   23.9292   25.9292  ]
#   ...
#   [31.22705  31.22705  31.22705 ]
#   [33.629395 33.629395 33.629395]
#   [29.720215 29.720215 29.720215]]
#
#  [[20.421875 24.421875 24.984375]
#   [27.930176 26.930176 32.930176]
#   [24.09375  25.09375  27.09375 ]
#   ...
#   [29.       29.       29.      ]
#   [31.65625  31.65625  31.65625 ]
#   [31.622559 31.622559 31.622559]]
#
#  ...
#
#  [[36.       36.       36.      ]
#   [40.       37.       32.      ]
#   [42.980957 37.980957 34.980957]
#   ...
#   [34.203125 27.203125 21.203125]
#   [30.       26.       23.      ]
#   [34.796875 26.796875 24.796875]]
#
#  [[37.21875  37.21875  37.21875 ]
#   [40.921875 35.921875 32.921875]
#   [43.       38.       35.      ]
#   ...
#   [33.086426 26.086426 20.086426]
#   [33.078125 29.078125 26.078125]
#   [34.375    26.375    23.375   ]]
#
#  [[35.43799  35.43799  35.43799 ]
#   [43.359375 39.       36.      ]
#   [43.265625 39.265625 36.265625]
#   ...
#   [35.90625  27.90625  24.90625 ]
#   [36.359375 31.359375 28.359375]
#   [34.50049  29.500488 25.500488]]]
# label: b'messi'
# Image: [[[ 19.5      23.5      22.5    ]
#   [ 24.       24.       26.     ]
#   [ 22.       22.       24.     ]
#   ...
#   [239.      245.      245.     ]
#   [236.84375 244.84375 246.84375]
#   [235.34375 241.34375 241.34375]]
#
#  [[ 20.03125  25.03125  21.03125]
#   [ 23.       23.       23.125  ]
#   [ 22.       22.       22.     ]
#   ...
#   [237.0625  243.0625  243.0625 ]
#   [235.      243.      245.     ]
#   [234.9375  240.9375  240.9375 ]]
#
#  [[ 21.       26.       20.     ]
#   [ 24.       24.       24.     ]
#   [ 22.       22.       20.     ]
#   ...
#   [235.      241.      241.     ]
#   [226.375   234.375   236.375  ]
#   [234.      240.      240.     ]]
#
#  ...
#
#  [[ 24.       24.       26.     ]
#   [ 24.5      25.       27.     ]
#   [ 25.5625   28.5625   33.5625 ]
#   ...
#   [172.09375 139.09375 121.09375]
#   [170.1875  142.1875  121.1875 ]
#   [170.46875 142.46875 121.46875]]
#
#  [[ 23.9375   23.9375   25.9375 ]
#   [ 24.375    24.875    26.875  ]
#   [ 22.9375   25.9375   30.9375 ]
#   ...
#   [174.4375  141.40625 126.5    ]
#   [168.5     143.4375  123.625  ]
#   [163.0625  136.0625  117.1875 ]]
#
#  [[ 22.       22.       24.     ]
#   [ 22.5      23.       25.     ]
#   [ 22.       25.       30.     ]
#   ...
#   [168.03125 136.03125 125.03125]
#   [160.78125 138.46875 122.125  ]
#   [163.65625 140.1875  124.34375]]]
# label: b'ronaldo'
# Image: [[[ 90.5 174.   72.5]
#   [ 90.5 175.5  77. ]
#   [ 92.  178.   79. ]
#   ...
#   [ 79.  164.   63. ]
#   [ 81.  166.   65. ]
#   [ 79.  164.   61. ]]
#
#  [[ 86.5 170.   68.5]
#   [ 86.  171.   72.5]
#   [ 88.5 174.5  75.5]
#   ...
#   [ 79.5 164.5  63.5]
#   [ 78.5 163.5  62.5]
#   [ 80.  165.   61. ]]
#
#  [[ 89.5 174.5  71.5]
#   [ 85.5 170.5  72. ]
#   [ 90.5 174.5  76.5]
#   ...
#   [ 75.  160.   59. ]
#   [ 75.5 159.   56.5]
#   [ 79.5 166.5  61.5]]
#
#  ...
#
#  [[ 69.5 155.5   2.5]
#   [ 71.  157.    4. ]
#   [ 75.5 161.5   8.5]
#   ...
#   [ 71.  156.    0.5]
#   [ 70.5 157.5   0.5]
#   [ 71.  158.    1. ]]
#
#  [[ 70.  156.    3. ]
#   [ 72.  157.    2. ]
#   [ 78.5 163.5   9.5]
#   ...
#   [ 72.  159.    2. ]
#   [ 68.  155.    0. ]
#   [ 71.5 158.5   1.5]]
#
#  [[ 75.  160.    7. ]
#   [ 76.5 160.5  10.5]
#   [ 76.  161.    7. ]
#   ...
#   [ 68.  155.    0. ]
#   [ 68.5 155.5   0. ]
#   [ 68.5 155.5   0. ]]]
# label: b'ronaldo'
# Image: [[[106.1875  87.1875  21.1875]
#   [113.      94.      28.    ]
#   [115.25    96.25    28.25  ]
#   ...
#   [ 20.0625  34.0625  71.0625]
#   [ 25.375   38.375   72.375 ]
#   [ 25.      36.      68.    ]]
#
#  [[108.      90.      24.    ]
#   [111.3125  93.3125  27.3125]
#   [111.625   92.625   23.625 ]
#   ...
#   [ 25.3125  39.3125  78.3125]
#   [ 20.5     33.5     68.5   ]
#   [ 29.5     39.5     74.5   ]]
#
#  [[106.125   88.125   22.125 ]
#   [108.375   90.375   24.375 ]
#   [113.1875  94.1875  25.1875]
#   ...
#   [ 24.375   38.375   77.375 ]
#   [ 28.      41.      76.    ]
#   [ 27.      37.      72.    ]]
#
#  ...
#
#  [[ 28.3125  43.3125  74.3125]
#   [ 30.4375  49.4375  81.4375]
#   [ 34.9375  49.9375  80.9375]
#   ...
#   [130.4375 156.4375 191.4375]
#   [141.125  175.125  212.125 ]
#   [158.3125 190.3125 229.3125]]
#
#  [[ 27.1875  42.1875  72.5625]
#   [ 27.25    44.6875  76.375 ]
#   [ 17.8125  32.8125  62.5625]
#   ...
#   [118.6875 145.6875 175.6875]
#   [134.6875 164.6875 198.6875]
#   [151.5    183.5    222.5   ]]
#
#  [[ 24.625   35.625   63.625 ]
#   [ 25.8125  39.8125  65.9375]
#   [ 23.5     37.5     63.5   ]
#   ...
#   [112.625  141.625  171.625 ]
#   [118.875  148.875  176.875 ]
#   [139.     172.     205.25  ]]]
# label: b'messi'

# %%
def scale(image, label):
    return image/255, label

# %%
train_ds = train_ds.map(scale)
for image, label in train_ds.take(5):
    print(f"Image: {image}")
    print(f"label: {label}")
# Out:
# Image: [[[0.29941788 0.31499502 0.3469401 ]
#   [0.30803654 0.3238875  0.34390318]
#   [0.31865233 0.33041704 0.35247588]
#   ...
#   [0.35936925 0.39466336 0.4534869 ]
#   [0.34879556 0.39905024 0.4522059 ]
#   [0.35629788 0.40479282 0.45897672]]
#
#  [[0.27034312 0.30104166 0.33107767]
#   [0.2791954  0.30664638 0.3301758 ]
#   [0.28918505 0.31663603 0.34062117]
#   ...
#   [0.34087968 0.3958161  0.4467965 ]
#   [0.34509805 0.39950982 0.4507353 ]
#   [0.35121593 0.3984777  0.45327818]]
#
#  [[0.24877451 0.28799018 0.3242896 ]
#   [0.26418504 0.29841068 0.32532743]
#   [0.2767157  0.30759802 0.3372549 ]
#   ...
#   [0.3372549  0.39215687 0.44313726]
#   [0.3467697  0.3938285  0.44088733]
#   [0.34730393 0.39436275 0.4492647 ]]
#
#  ...
#
#  [[0.51893955 0.36991996 0.4130572 ]
#   [0.501011   0.35199142 0.39512867]
#   [0.47340685 0.32953238 0.3587929 ]
#   ...
#   [0.4189951  0.3915441  0.36017156]
#   [0.5760589  0.5682158  0.52115697]
#   [0.67126226 0.655576   0.60851717]]
#
#  [[0.5389189  0.38989928 0.43323952]
#   [0.51366615 0.36464652 0.40778378]
#   [0.47791055 0.34065562 0.3681066 ]
#   ...
#   [0.42928922 0.41360295 0.37830883]
#   [0.57487935 0.5591931  0.513084  ]
#   [0.6797794  0.66409314 0.6170343 ]]
#
#  [[0.56272787 0.40586513 0.4490024 ]
#   [0.54330957 0.3924326  0.43556985]
#   [0.5032724  0.3569489  0.39199793]
#   ...
#   [0.4771695  0.46148324 0.41720665]
#   [0.5834865  0.5834865  0.5364277 ]
#   [0.6606139  0.65277076 0.60179037]]]
# label: b'messi'
# Image: [[[0.10958204 0.13703302 0.10958204]
#   [0.13307291 0.14091605 0.12130821]
#   [0.16078432 0.18039216 0.15686275]
#   ...
#   [0.20396753 0.19220282 0.17259498]
#   [0.22983518 0.23375675 0.21414891]
#   [0.23921569 0.24313726 0.22352941]]
#
#  [[0.09019608 0.1254902  0.12156863]
#   [0.10980392 0.14117648 0.14901961]
#   [0.14108455 0.18814339 0.17245711]
#   ...
#   [0.1961172  0.19219564 0.1725878 ]
#   [0.21712503 0.2069841  0.18737626]
#   [0.20850877 0.2045872  0.18497936]]
#
#  [[0.08929874 0.12459286 0.12067129]
#   [0.10449961 0.14371529 0.14530843]
#   [0.14386919 0.18308489 0.17916332]
#   ...
#   [0.23965825 0.23965825 0.2082857 ]
#   [0.22755007 0.22755007 0.19617753]
#   [0.21520254 0.21520254 0.17598686]]
#
#  ...
#
#  [[0.4349966  0.5604868  0.18009464]
#   [0.46191072 0.5795578  0.20308718]
#   [0.41438755 0.5320346  0.15556401]
#   ...
#   [0.4015608  0.5152863  0.15058044]
#   [0.41281763 0.51477844 0.15791567]
#   [0.42856038 0.5344427  0.16973685]]
#
#  [[0.43598345 0.5598192  0.18439032]
#   [0.44347978 0.5611268  0.18465625]
#   [0.42135417 0.5390012  0.16253063]
#   ...
#   [0.3764706  0.47843137 0.12493059]
#   [0.40770215 0.52142763 0.15672177]
#   [0.3822931  0.48817545 0.12346958]]
#
#  [[0.413304   0.52702945 0.1623236 ]
#   [0.40340075 0.53673404 0.16418505]
#   [0.4312677  0.5449932  0.18028732]
#   ...
#   [0.3372944  0.45101988 0.086314  ]
#   [0.35052922 0.45641157 0.09170568]
#   [0.34015012 0.4421109  0.0863511 ]]]
# label: b'messi'
# Image: [[[0.44224876 0.36749387 0.36173406]
#   [0.4179994  0.34362745 0.33767617]
#   [0.39244792 0.34352022 0.33089   ]
#   ...
#   [0.5452053  0.46861213 0.47721353]
#   [0.52707565 0.44044885 0.45081955]
#   [0.51499695 0.45438114 0.46600798]]
#
#  [[0.43564644 0.37143075 0.36372548]
#   [0.38692555 0.32393536 0.32100183]
#   [0.38769916 0.3322074  0.3314032 ]
#   ...
#   [0.58764553 0.50249696 0.5094822 ]
#   [0.5526501  0.47299325 0.47973347]
#   [0.5667892  0.4716069  0.48380822]]
#
#  [[0.42987898 0.36861214 0.38111213]
#   [0.39303768 0.32823223 0.32485446]
#   [0.3630821  0.31577054 0.32369792]
#   ...
#   [0.6126685  0.5151118  0.5282246 ]
#   [0.584758   0.4922258  0.50225186]
#   [0.585432   0.49302235 0.5054764 ]]
#
#  ...
#
#  [[0.5662837  0.67830116 0.39384958]
#   [0.5494562  0.67813265 0.40729934]
#   [0.5589461  0.67879903 0.38986674]
#   ...
#   [0.57850033 0.68361676 0.45375305]
#   [0.5635723  0.6814185  0.44283855]
#   [0.5757123  0.68074447 0.44237897]]
#
#  [[0.5505744  0.67410386 0.39309895]
#   [0.5498085  0.6737362  0.38354012]
#   [0.5585554  0.6788986  0.39078584]
#   ...
#   [0.579205   0.680553   0.4538373 ]
#   [0.582261   0.6850337  0.4517846 ]
#   [0.5824755  0.6826134  0.43989736]]
#
#  [[0.5408701  0.66821384 0.39762563]
#   [0.5376915  0.6678385  0.3795343 ]
#   [0.5477941  0.676731   0.39153644]
#   ...
#   [0.56959254 0.6821308  0.4498851 ]
#   [0.5730086  0.6822151  0.44140625]
#   [0.5700827  0.6802773  0.44929534]]]
# label: b'messi'
# Image: [[[0.27466142 0.21975948 0.21583791]
#   [0.27011335 0.2269761  0.21913296]
#   [0.26574    0.22260275 0.21475962]
#   ...
#   [0.373296   0.3615313  0.42819795]
#   [0.38039216 0.37254903 0.42745098]
#   [0.3619501  0.33842066 0.38554233]]
#
#  [[0.29847047 0.2442119  0.24485527]
#   [0.2963555  0.24929667 0.24929667]
#   [0.26908702 0.22202818 0.22202818]
#   ...
#   [0.39701724 0.38525254 0.45976233]
#   [0.37247375 0.36038736 0.42705402]
#   [0.3656663  0.33037218 0.40488198]]
#
#  [[0.28509107 0.258115   0.267107  ]
#   [0.3141391  0.27802506 0.29019973]
#   [0.29067096 0.2475337  0.23969056]
#   ...
#   [0.3809395  0.36917478 0.4436846 ]
#   [0.3824828  0.35462186 0.42643994]
#   [0.35393324 0.3181679  0.39283478]]
#
#  ...
#
#  [[0.39784008 0.39898896 0.48965994]
#   [0.46577454 0.47361767 0.52459806]
#   [0.5454227  0.53757954 0.5885599 ]
#   ...
#   [0.28079045 0.22981004 0.1984375 ]
#   [0.2886562  0.2376758  0.20630325]
#   [0.28918505 0.23820466 0.20683211]]
#
#  [[0.41628602 0.42412916 0.51202744]
#   [0.47835347 0.47835347 0.52541226]
#   [0.5296532  0.52181005 0.5649473 ]
#   ...
#   [0.29818875 0.24720836 0.21583581]
#   [0.28362438 0.23264399 0.20127144]
#   [0.2904235  0.23944314 0.20807058]]
#
#  [[0.4363672  0.42083254 0.51095283]
#   [0.4819723  0.489588   0.5404871 ]
#   [0.5179228  0.5100797  0.5608456 ]
#   ...
#   [0.2865962  0.2356158  0.20424326]
#   [0.29027733 0.23929694 0.20411006]
#   [0.28596425 0.23498386 0.2036113 ]]]
# label: b'messi'
# Image: [[[0.38039216 0.38431373 0.36078432]
#   [0.40980393 0.40588236 0.3882353 ]
#   [0.3764706  0.38039216 0.3509804 ]
#   ...
#   [0.30784315 0.32352942 0.33529413]
#   [0.30294117 0.31470588 0.33431372]
#   [0.29705882 0.3127451  0.3245098 ]]
#
#  [[0.34117648 0.34117648 0.33333334]
#   [0.34901962 0.34901962 0.34117648]
#   [0.34509805 0.34509805 0.34509805]
#   ...
#   [0.29803923 0.30980393 0.32941177]
#   [0.3127451  0.3245098  0.34411764]
#   [0.31176472 0.32352942 0.34313726]]
#
#  [[0.3362745  0.34411764 0.34019607]
#   [0.32941177 0.32941177 0.32156864]
#   [0.3529412  0.3529412  0.36078432]
#   ...
#   [0.29215688 0.30392158 0.32352942]
#   [0.3107843  0.32254902 0.34215686]
#   [0.30784315 0.31960785 0.3392157 ]]
#
#  ...
#
#  [[0.30588236 0.39607844 0.23137255]
#   [0.3137255  0.39019608 0.23921569]
#   [0.28627452 0.38431373 0.22745098]
#   ...
#   [0.2254902  0.19019608 0.9352941 ]
#   [0.19411765 0.16764706 0.88039213]
#   [0.1637255  0.1382353  0.85490197]]
#
#  [[0.32156864 0.38431373 0.23921569]
#   [0.29803923 0.38039216 0.22745098]
#   [0.26568627 0.3852941  0.22058824]
#   ...
#   [0.17058824 0.14705883 0.77254903]
#   [0.1764706  0.16568628 0.78431374]
#   [0.22058824 0.20686275 0.7745098 ]]
#
#  [[0.3156863  0.38235295 0.24117647]
#   [0.30294117 0.38921568 0.23627451]
#   [0.27941176 0.3852941  0.20882353]
#   ...
#   [0.11960784 0.09803922 0.6764706 ]
#   [0.08529412 0.08137255 0.5833333 ]
#   [0.32352942 0.29705882 0.9519608 ]]]
# label: b'ronaldo'
